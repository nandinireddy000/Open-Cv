# %%
import cv2
img1 = cv2.imread(r"C:\Users\marun\Downloads\flower.jpg")
cv2.imwrite(r"C:\Users\marun\Downloads\output.jpg", img1)
print("Image saved Successfully")
# Out:
# Image saved Successfully

# %%
import cv2
img1 = cv2.imread(r"C:\Users\marun\Downloads\flower.jpg")
print(img1 is None)
# Out:
# False

# %%
from IPython.display import Image, display
display(Image(filename= r"C:\Users\marun\Downloads\output.jpg"))
