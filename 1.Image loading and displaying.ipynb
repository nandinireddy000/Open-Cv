# %%
import cv2
print("openCV Version:", cv2.__version__)
# Out:
# openCV Version: 4.13.0

# %%
import cv2
from matplotlib import pyplot as plt
img = cv2.imread(r"C:\Users\marun\Downloads\flower.jpg")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
