# %%
from skimage import io
img = io.imread(r"C:\Users\marun\Downloads\dog.jpg")
img.shape
# Out:
# (503, 406, 3)

# %%
import cv2
import matplotlib.pyplot as plt
img = io.imread(r"C:\Users\marun\Downloads\dog.jpg")
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

img_bgr = cv2.cvtColor(img_hsv,cv2.COLOR_HSV2RGB)
figure(0)
io.imshow(cv2.cvtColor(img_hsv,cv2.COLOR_HSV2RGB))
plt.figure("HSV Image")
plt.figure(1)
plt.imshow(cv2.cvtColor(img_bgr,cv2.COLOR_BGR2RGB))
plt.title("RGB Image")
plt.show()
# Out:
# C:\Users\marun\AppData\Local\Temp\ipykernel_14548\3126441443.py:8: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(cv2.cvtColor(img_hsv,cv2.COLOR_HSV2RGB))
